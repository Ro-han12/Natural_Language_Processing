# %%
import nltk 
nltk.download('book')
# Out:
# [nltk_data] Downloading collection 'book'
# [nltk_data]    |
# [nltk_data]    | Downloading package abc to
# [nltk_data]    |     /Users/rohansridhar/nltk_data...
# [nltk_data]    |   Unzipping corpora/abc.zip.
# [nltk_data]    | Downloading package brown to
# [nltk_data]    |     /Users/rohansridhar/nltk_data...
# [nltk_data]    |   Package brown is already up-to-date!
# [nltk_data]    | Downloading package chat80 to
# [nltk_data]    |     /Users/rohansridhar/nltk_data...
# [nltk_data]    |   Unzipping corpora/chat80.zip.
# [nltk_data]    | Downloading package cmudict to
# [nltk_data]    |     /Users/rohansridhar/nltk_data...
# [nltk_data]    |   Unzipping corpora/cmudict.zip.
# [nltk_data]    | Downloading package conll2000 to
# [nltk_data]    |     /Users/rohansridhar/nltk_data...
# [nltk_data]    |   Unzipping corpora/conll2000.zip.
# [nltk_data]    | Downloading package conll2002 to
# [nltk_data]    |     /Users/rohansridhar/nltk_data...
# ...

# %%
def lexical_richness(text):
    return len(text)/ len(set(text))
def percentage(count,total):
    return 100*(count/total)

# %%
from nltk.book import *
# Out:
# *** Introductory Examples for the NLTK Book ***
# Loading text1, ..., text9 and sent1, ..., sent9
# Type the name of the text or sentence to view it.
# Type: 'texts()' or 'sents()' to list the materials.
# text1: Moby Dick by Herman Melville 1851
# text2: Sense and Sensibility by Jane Austen 1811
# text3: The Book of Genesis
# text4: Inaugural Address Corpus
# text5: Chat Corpus
# text6: Monty Python and the Holy Grail
# text7: Wall Street Journal
# text8: Personals Corpus
# text9: The Man Who Was Thursday by G . K . Chesterton 1908

# %%
lexical_richness(text3) #lexical rinchness of text3
# Out:
# 16.050197203298673

# %%
percentage(text3.count('a'),len(text3))
# Out:
# 0.7640067911714771

# %%
freq=FreqDist(text1)
freq
# Out:
# FreqDist({',': 18713, 'the': 13721, '.': 6862, 'of': 6536, 'and': 6024, 'a': 4569, 'to': 4542, ';': 4072, 'in': 3916, 'that': 2982, ...})

# %%
import matplotlib.pyplot as plt 
freq.plot(50,cumulative=True)
# Out:
# <Axes: xlabel='Samples', ylabel='Cumulative Counts'>

# %%
freq.hapaxes()
# Out:
# ['Herman',
#  'Melville',
#  ']',
#  'ETYMOLOGY',
#  'Late',
#  'Consumptive',
#  'School',
#  'threadbare',
#  'lexicons',
#  'mockingly',
#  'flags',
#  'mortality',
#  'signification',
#  'HACKLUYT',
#  'Sw',
#  'HVAL',
#  'roundness',
#  'Dut',
#  'Ger',
#  'WALLEN',
#  'WALW',
#  'IAN',
#  'RICHARDSON',
#  'KETOS',
#  'GREEK',
#  'CETUS',
#  'LATIN',
#  'WHOEL',
#  'ANGLO',
#  'SAXON',
#  'WAL',
#  'HWAL',
#  'SWEDISH',
#  'ICELANDIC',
#  'BALEINE',
#  'BALLENA',
#  'FEGEE',
#  'ERROMANGOAN',
#  'Librarian',
#  'painstaking',
#  'burrower',
#  'grub',
#  'Vaticans',
#  'stalls',
#  'higgledy',
#  'piggledy',
#  'gospel',
#  'promiscuously',
#  'commentator',
#  'belongest',
#  'sallow',
#  'Pale',
#  'Sherry',
#  'loves',
#  'bluntly',
#  'Subs',
#  'thankless',
#  'Hampton',
#  'Court',
#  'hie',
#  'refugees',
#  'pampered',
#  'Michael',
#  'Raphael',
#  'unsplinterable',
#  'GENESIS',
#  'JOB',
#  'JONAH',
#  'punish',
#  'ISAIAH',
#  'soever',
#  'cometh',
# ...

# %%
text=set(text3)
count=[word for word in text if len(word)>2]
print("count of words more than len 15 are:",count)
# Out:
# count of words more than len 15 are: ['peaceably', 'Naphtali', 'faults', 'garmen', 'lift', 'loved', 'prosperous', 'appoint', 'withheld', 'issue', 'space', 'worse', 'better', 'gard', 'flo', 'males', 'Eve', 'fair', 'ninety', 'after', 'through', 'Ask', 'rul', 'Cheran', 'threshingfloor', 'morning', 'stories', 'arose', 'Ajah', 'Heaven', 'laden', 'without', 'establish', 'you', 'following', 'done', 'Two', 'bed', 'dwelling', 'Laban', 'rid', 'sole', 'their', 'names', 'savoury', 'Both', 'Where', 'hold', 'kids', 'requite', 'Cush', 'deceitfully', 'multiply', 'displease', 'child', 'Machpelah', 'Wilt', 'Adullamite', 'waxen', 'Leummim', 'Amorite', 'leanfleshed', 'citi', 'given', 'Girgashites', 'Ephrath', 'scarlet', 'servan', 'Shaul', 'stooped', 'giveth', 'weaned', 'put', 'wicked', 'ready', 'Muppim', 'edge', 'Ararat', 'for', 'findeth', 'covering', 'Perizzites', 'drinking', 'sawest', 'led', 'Jeush', 'eyes', 'Fill', 'cru', 'daughters', 'overdrive', 'gold', 'Euphrates', 'bracelets', 'said', 'raiment', 
# ...

# %%
text=FreqDist(text3)
count1=sorted([word for word in set(text) if len(word)>7 and text[word]>7])
count
# Out:
# ['peaceably',
#  'Naphtali',
#  'faults',
#  'garmen',
#  'lift',
#  'loved',
#  'prosperous',
#  'appoint',
#  'withheld',
#  'issue',
#  'space',
#  'worse',
#  'better',
#  'gard',
#  'flo',
#  'males',
#  'Eve',
#  'fair',
#  'ninety',
#  'after',
#  'through',
#  'Ask',
#  'rul',
#  'Cheran',
#  'threshingfloor',
#  'morning',
#  'stories',
#  'arose',
#  'Ajah',
#  'Heaven',
#  'laden',
#  'without',
#  'establish',
#  'you',
#  'following',
#  'done',
#  'Two',
#  'bed',
#  'dwelling',
#  'Laban',
#  'rid',
#  'sole',
#  'their',
#  'names',
#  'savoury',
#  'Both',
#  'Where',
#  'hold',
#  'kids',
#  'requite',
#  'Cush',
#  'deceitfully',
#  'multiply',
#  'displease',
#  'child',
#  'Machpelah',
#  'Wilt',
#  'Adullamite',
#  'waxen',
#  'Leummim',
#  'Amorite',
#  'leanfleshed',
#  'citi',
#  'given',
#  'Girgashites',
#  'Ephrath',
#  'scarlet',
#  'servan',
#  'Shaul',
#  'stooped',
#  'giveth',
#  'weaned',
#  'put',
#  'wicked',
#  'ready',
#  'Muppim',
#  'edge',
# ...
